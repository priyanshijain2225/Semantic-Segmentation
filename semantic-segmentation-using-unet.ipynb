# %%
import tensorflow as tf
import tensorflow.keras.layers as tfl
import os
from tqdm import tqdm
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans
from PIL import Image
from os.path import splitext

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Loading Data & Data Preprocessing</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">First using the OS library I'll upload the cityscapes pair images.</p>

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
path='../input/cityscapes-image-pairs'
def images_upload(path):
    images=[]
    for root,subfolders,files in os.walk(path):
        for file in tqdm(files):
            filename=root+os.sep+file
            if filename.endswith('jpg') or filename.endwith('png'):
                images.append(filename)
    return images
images=images_upload(path)
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100%|██████████| 500/500 [00:00<00:00, 944237.73it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 1520601.32it/s]
# 100%|██████████| 500/500 [00:00<00:00, 749786.20it/s]
# 100%|██████████| 2975/2975 [00:00<00:00, 1555091.53it/s]

# %%
def convert_image_rgb(data):
    imgs=[]
    for i in tqdm(data):
        img = cv2.imread(i,cv2.COLOR_BGR2RGB)
        del i
        imgs.append(img)
    return imgs
img=convert_image_rgb(images)
# Out:
# 100%|██████████| 6950/6950 [02:48<00:00, 41.19it/s]

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Let us look at one of the images. It can be seen that the image contains both the real image and the mask, so the next task will be to distinguish between them. Randmoly has selected the following image.</p>

# %%
plt.imshow(img[np.random.randint(0,len(img))]);

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">Because the image shape is 512*256, it should be divided into two groups, real images and mask images, at 256 pixels on the x axis.</p>

# %%
def split_input_mask(data):
    inputs=[]
    mask=[]
    for i in data:
        a=i[:,:256]
        inputs.append(a)
        b=i[:,256:]
        mask.append(b)
    return inputs,mask
inputs,mask=split_input_mask(img)

# %%
del images
del img

# %% [markdown]
# <p style="padding: 10px;color:black;font-size:120%;font-family: Times New Roman, Times, serif;">In this section, I'll show a few images of the real images as well as a few images of the mask images after they've been separated.</p>

# %%
def show_images(data):
    plt.figure(figsize=(10,10))
    for i in range(9):
        idx=np.random.randint(0,len(data))
        plt.subplot(3,3,i+1)
        img=data[idx]
        plt.imshow(img)
show_images(inputs)

# %%
show_images(mask)

# %%
def images_compare(inputs,mask):
    idx_new=np.random.randint(0,len(mask))
    fig = plt.figure()
    ax1 = fig.add_subplot(1,2,1)
    ax1.imshow(mask[idx_new])
    ax2 = fig.add_subplot(1,2,2)
    ax2.imshow(inputs[idx_new],cmap='gray')
    plt.show()
images_compare(inputs,mask)

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Labeling using K-means</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;">Although each pixel in these images is labeled, it was still necessary to separate the different colors to labels. K-means will be used to categorize these colored labels into ten different groups. This is a hyperparameter. The next few labeled images will be shown, followed by rescaling of the original image.</p>

# %%
num_items = 1000
color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
num_classes = 20
label_model = KMeans(n_clusters = num_classes)
label_model.fit(color_array)
label_class = label_model.predict(mask[10].reshape(-1,3)).reshape(256,256)
fig, axes = plt.subplots(1,3,figsize=(15,5))
axes[0].imshow(inputs[10]);
axes[1].imshow(mask[10]);
axes[2].imshow(label_class);

# %%
def new_labels(mask):
    num_items = 1000
    color_array = np.random.choice(range(256), 3*num_items).reshape(-1,3)
    num_classes = 10
    label_model = KMeans(n_clusters = num_classes)
    label_model.fit(color_array)
    labels=[]
    for i in tqdm(range(len(mask))):
        label_class = label_model.predict(mask[i].reshape(-1,3)).reshape(256,256)
        labels.append(label_class)
    return labels

# %%
labels=new_labels(mask)
idx=np.random.randint(0,len(labels))
classes,freq=np.unique(labels[idx],return_counts=True)
print(f'number of classes :{len(classes)}')
# Out:
# 100%|██████████| 6950/6950 [00:22<00:00, 312.13it/s]
# number of classes :8

# %%
plt.figure(figsize=(10,10))
for i in range(9):
        plt.subplot(3,3,i+1)
        im=labels[i]
        plt.imshow(im)
# plt.imshow(a)

# %%
def rescale(data):
    rescaled=[]
    for i in tqdm(data):
        img=tf.image.convert_image_dtype(i, tf.float32)
        del i
        rescaled.append(img)
    return rescaled

# %%
rescaled_input=rescale(inputs)
# Out:
# 100%|██████████| 6950/6950 [00:05<00:00, 1309.19it/s]

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Buliding the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> Here I'm using UNet since the position of the object is crucial for this task. The feature map is upsampled to the size of the original input image using a transposed convolution layer that preserves the spatial information. It also includes skip connections, which help to keep information that would otherwise be lost during encoding. This model is kind of mini-VGG. </p>

# %%
def build_model(inputsize=(256,256,3),classes=None):
    inputs = tf.keras.Input(shape=(inputsize))

    conv = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv1')(
        inputs)
    x=tfl.BatchNormalization()(conv)
    x=tfl.LeakyReLU()(x)
    x1 = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv2')(
        x)
    x=tfl.BatchNormalization()(x1)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool1')(x)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv3')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x2 = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv4')(x)
    x=tfl.BatchNormalization()(x2)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), name='MaxPool2')(x)

    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv5')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x3 = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv6')(x)
    x=tfl.BatchNormalization()(x3)
    x=tfl.LeakyReLU()(x)
    x = tfl.MaxPool2D(pool_size=(2, 2), strides=(2, 2), name='MaxPool3')(x)

    
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv7')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(256, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv8')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(128, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x3], axis=3)
    
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv9')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(128, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv10')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2DTranspose(64, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x2], axis=3)

    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv11')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(64, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv12')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    x = tfl.Conv2DTranspose(32, (3, 3), strides=2, padding="same")(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)

    x = tfl.concatenate([x, x1], axis=3)

    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv25')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    x = tfl.Conv2D(32, (3, 3), padding="same",kernel_initializer='he_normal', name='Conv26')(x)
    x=tfl.BatchNormalization()(x)
    x=tfl.LeakyReLU()(x)
    
    outputs = tfl.Conv2D(classes, (1, 1), padding="same", activation='softmax', name='Outputs')(x)
    final_model = tf.keras.Model(inputs=inputs, outputs=outputs)
    final_model.summary()
    return final_model

# %%
mymodel=build_model(classes=10)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu (LeakyReLU)         (None, 256, 256, 32) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# Conv2 (Conv2D)                  (None, 256, 256, 32) 9248        leaky_re_lu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 32) 128         Conv2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 256, 256, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# MaxPool1 (MaxPooling2D)         (None, 128, 128, 32) 0           leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# Conv3 (Conv2D)                  (None, 128, 128, 64) 18496       MaxPool1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 128, 128, 64) 256         Conv3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# Conv4 (Conv2D)                  (None, 128, 128, 64) 36928       leaky_re_lu_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 128, 128, 64) 256         Conv4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 128, 128, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# MaxPool2 (MaxPooling2D)         (None, 64, 64, 64)   0           leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# Conv5 (Conv2D)                  (None, 64, 64, 128)  73856       MaxPool2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 64, 64, 128)  512         Conv5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# Conv6 (Conv2D)                  (None, 64, 64, 128)  147584      leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 64, 64, 128)  512         Conv6[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# MaxPool3 (MaxPooling2D)         (None, 32, 32, 128)  0           leaky_re_lu_5[0][0]
# __________________________________________________________________________________________________
# Conv7 (Conv2D)                  (None, 32, 32, 256)  295168      MaxPool3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 32, 32, 256)  1024        Conv7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# Conv8 (Conv2D)                  (None, 32, 32, 256)  590080      leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 32, 32, 256)  1024        Conv8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 32, 32, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 64, 64, 128)  295040      leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 64, 64, 128)  512         conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 64, 64, 256)  0           leaky_re_lu_8[0][0]
#                                                                  Conv6[0][0]
# __________________________________________________________________________________________________
# Conv9 (Conv2D)                  (None, 64, 64, 128)  295040      concatenate[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 64, 64, 128)  512         Conv9[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 64, 64, 128)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# Conv10 (Conv2D)                 (None, 64, 64, 128)  147584      leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 64, 64, 128)  512         Conv10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 64, 64, 128)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 128, 128, 64) 73792       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 128, 128, 64) 256         conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 128, 128, 128 0           leaky_re_lu_11[0][0]
#                                                                  Conv4[0][0]
# __________________________________________________________________________________________________
# Conv11 (Conv2D)                 (None, 128, 128, 64) 73792       concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 128, 128, 64) 256         Conv11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# Conv12 (Conv2D)                 (None, 128, 128, 64) 36928       leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 128, 128, 64) 256         Conv12[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 128, 128, 64) 0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 256, 256, 32) 18464       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 256, 256, 32) 128         conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 256, 256, 64) 0           leaky_re_lu_14[0][0]
#                                                                  Conv2[0][0]
# __________________________________________________________________________________________________
# Conv25 (Conv2D)                 (None, 256, 256, 32) 18464       concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 256, 256, 32) 128         Conv25[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# Conv26 (Conv2D)                 (None, 256, 256, 32) 9248        leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 256, 256, 32) 128         Conv26[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 256, 256, 32) 0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# Outputs (Conv2D)                (None, 256, 256, 10) 330         leaky_re_lu_16[0][0]
# ==================================================================================================
# Total params: 2,147,466
# Trainable params: 2,144,202
# Non-trainable params: 3,264
# __________________________________________________________________________________________________

# %%
img_file = './model_arch.png'

tf.keras.utils.plot_model(mymodel, to_file=img_file, show_shapes=True, show_layer_names=True)

# %%
del inputs

# %% [markdown]
#  <div style="color:black;
#            display:fill;
#            border-radius:5px;
#            font-size:300%;
#            font-family: Times New Roman, Times, serif;
#     letter-spacing:0.5px"><b>Training the model</b>
#
# <p style="padding: 10px;color:black;font-size:40%;font-family: Times New Roman, Times, serif;"> The data is divided into train and test segments, with each segment accounting for 80% and 20% of the total. To prevent RAM memory from crashing, I'm using 1300 images. Because the model's output employs 'softmax' activation layer, the loss function is sparse categorical crossentropy. Next, I'm going to use argmax to return the index with the highest value, and then I'm going to make some predictions for the test.</p>

# %%
def split_data(x,y,test_size=0.2):
    x1=np.array(x)
    del x
    y1=np.array(y)
    del y
    x_train, x_test, y_train, y_test = train_test_split(x1, y1, test_size=test_size)
    return  x_train, x_test, y_train, y_test

# %%
 x_train, x_test, y_train, y_test=split_data(rescaled_input[:1300],labels[:1300],test_size=0.2)

# %%
def callbacks(patience=5):
    checkpoint = tf.keras.callbacks.ModelCheckpoint('seg_model.h5', monitor='loss', verbose=1, save_best_only=True, save_weights_only=True)
    early=tf.keras.callbacks.EarlyStopping(monitor='loss',patience=patience)
    callbacks_list=[checkpoint, early]
    return callbacks_list

# %%
mymodel.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),loss=tf.keras.losses.sparse_categorical_crossentropy,metrics=['acc'])
hist=mymodel.fit(x_train,y_train,batch_size=16,epochs=200,callbacks=callbacks())
# Out:
# Epoch 1/200
# 65/65 [==============================] - 20s 173ms/step - loss: 1.1376 - acc: 0.6383
#
# Epoch 00001: loss improved from inf to 1.13757, saving model to seg_model.h5
# Epoch 2/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.9113 - acc: 0.6961
#
# Epoch 00002: loss improved from 1.13757 to 0.91129, saving model to seg_model.h5
# Epoch 3/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.8416 - acc: 0.7166
#
# Epoch 00003: loss improved from 0.91129 to 0.84156, saving model to seg_model.h5
# Epoch 4/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.7965 - acc: 0.7306
#
# Epoch 00004: loss improved from 0.84156 to 0.79653, saving model to seg_model.h5
# Epoch 5/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.7403 - acc: 0.7505
#
# Epoch 00005: loss improved from 0.79653 to 0.74034, saving model to seg_model.h5
# Epoch 6/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.7042 - acc: 0.7617
#
# Epoch 00006: loss improved from 0.74034 to 0.70421, saving model to seg_model.h5
# Epoch 7/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.6803 - acc: 0.7707
#
# Epoch 00007: loss improved from 0.70421 to 0.68035, saving model to seg_model.h5
# Epoch 8/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.6616 - acc: 0.7784
#
# Epoch 00008: loss improved from 0.68035 to 0.66156, saving model to seg_model.h5
# Epoch 9/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.6348 - acc: 0.7875
#
# Epoch 00009: loss improved from 0.66156 to 0.63479, saving model to seg_model.h5
# Epoch 10/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.6147 - acc: 0.7951
#
# Epoch 00010: loss improved from 0.63479 to 0.61466, saving model to seg_model.h5
# Epoch 11/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.6015 - acc: 0.7998
#
# Epoch 00011: loss improved from 0.61466 to 0.60145, saving model to seg_model.h5
# Epoch 12/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5832 - acc: 0.8068
#
# Epoch 00012: loss improved from 0.60145 to 0.58324, saving model to seg_model.h5
# Epoch 13/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5746 - acc: 0.8091
#
# Epoch 00013: loss improved from 0.58324 to 0.57457, saving model to seg_model.h5
# Epoch 14/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5646 - acc: 0.8126
#
# Epoch 00014: loss improved from 0.57457 to 0.56457, saving model to seg_model.h5
# Epoch 15/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5537 - acc: 0.8174
#
# Epoch 00015: loss improved from 0.56457 to 0.55371, saving model to seg_model.h5
# Epoch 16/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5337 - acc: 0.8229
#
# Epoch 00016: loss improved from 0.55371 to 0.53374, saving model to seg_model.h5
# Epoch 17/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5330 - acc: 0.8228
#
# Epoch 00017: loss improved from 0.53374 to 0.53299, saving model to seg_model.h5
# Epoch 18/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5221 - acc: 0.8274
#
# Epoch 00018: loss improved from 0.53299 to 0.52214, saving model to seg_model.h5
# Epoch 19/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5177 - acc: 0.8273
#
# Epoch 00019: loss improved from 0.52214 to 0.51767, saving model to seg_model.h5
# Epoch 20/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5117 - acc: 0.8290
#
# Epoch 00020: loss improved from 0.51767 to 0.51165, saving model to seg_model.h5
# Epoch 21/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.5007 - acc: 0.8339
#
# Epoch 00021: loss improved from 0.51165 to 0.50068, saving model to seg_model.h5
# Epoch 22/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4930 - acc: 0.8370
#
# Epoch 00022: loss improved from 0.50068 to 0.49300, saving model to seg_model.h5
# Epoch 23/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4954 - acc: 0.8357
#
# Epoch 00023: loss did not improve from 0.49300
# Epoch 24/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4867 - acc: 0.8377
#
# Epoch 00024: loss improved from 0.49300 to 0.48674, saving model to seg_model.h5
# Epoch 25/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4780 - acc: 0.8404
#
# Epoch 00025: loss improved from 0.48674 to 0.47803, saving model to seg_model.h5
# Epoch 26/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4776 - acc: 0.8411
#
# Epoch 00026: loss improved from 0.47803 to 0.47758, saving model to seg_model.h5
# Epoch 27/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4681 - acc: 0.8436
#
# Epoch 00027: loss improved from 0.47758 to 0.46814, saving model to seg_model.h5
# Epoch 28/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4687 - acc: 0.8434
#
# Epoch 00028: loss did not improve from 0.46814
# Epoch 29/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4643 - acc: 0.8445
#
# Epoch 00029: loss improved from 0.46814 to 0.46428, saving model to seg_model.h5
# Epoch 30/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4514 - acc: 0.8488
#
# Epoch 00030: loss improved from 0.46428 to 0.45142, saving model to seg_model.h5
# Epoch 31/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4533 - acc: 0.8480
#
# Epoch 00031: loss did not improve from 0.45142
# Epoch 32/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4561 - acc: 0.8472
#
# Epoch 00032: loss did not improve from 0.45142
# Epoch 33/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4410 - acc: 0.8513
#
# Epoch 00033: loss improved from 0.45142 to 0.44104, saving model to seg_model.h5
# Epoch 34/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4408 - acc: 0.8513
#
# Epoch 00034: loss improved from 0.44104 to 0.44084, saving model to seg_model.h5
# Epoch 35/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4328 - acc: 0.8538
#
# Epoch 00035: loss improved from 0.44084 to 0.43283, saving model to seg_model.h5
# Epoch 36/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4336 - acc: 0.8538
#
# Epoch 00036: loss did not improve from 0.43283
# Epoch 37/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4312 - acc: 0.8545
#
# Epoch 00037: loss improved from 0.43283 to 0.43122, saving model to seg_model.h5
# Epoch 38/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4240 - acc: 0.8565
#
# Epoch 00038: loss improved from 0.43122 to 0.42396, saving model to seg_model.h5
# Epoch 39/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4268 - acc: 0.8552
#
# Epoch 00039: loss did not improve from 0.42396
# Epoch 40/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4191 - acc: 0.8583
#
# Epoch 00040: loss improved from 0.42396 to 0.41910, saving model to seg_model.h5
# Epoch 41/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4224 - acc: 0.8569
#
# Epoch 00041: loss did not improve from 0.41910
# Epoch 42/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4137 - acc: 0.8596
#
# Epoch 00042: loss improved from 0.41910 to 0.41369, saving model to seg_model.h5
# Epoch 43/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4054 - acc: 0.8624
#
# Epoch 00043: loss improved from 0.41369 to 0.40541, saving model to seg_model.h5
# Epoch 44/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3966 - acc: 0.8649
#
# Epoch 00044: loss improved from 0.40541 to 0.39660, saving model to seg_model.h5
# Epoch 45/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.4032 - acc: 0.8631
#
# Epoch 00045: loss did not improve from 0.39660
# Epoch 46/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3969 - acc: 0.8650
#
# Epoch 00046: loss did not improve from 0.39660
# Epoch 47/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3879 - acc: 0.8674
#
# Epoch 00047: loss improved from 0.39660 to 0.38791, saving model to seg_model.h5
# Epoch 48/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3838 - acc: 0.8686
#
# Epoch 00048: loss improved from 0.38791 to 0.38380, saving model to seg_model.h5
# Epoch 49/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3887 - acc: 0.8674
#
# Epoch 00049: loss did not improve from 0.38380
# Epoch 50/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3850 - acc: 0.8679
#
# Epoch 00050: loss did not improve from 0.38380
# Epoch 51/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3826 - acc: 0.8692
#
# Epoch 00051: loss improved from 0.38380 to 0.38255, saving model to seg_model.h5
# Epoch 52/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3691 - acc: 0.8741
#
# Epoch 00052: loss improved from 0.38255 to 0.36915, saving model to seg_model.h5
# Epoch 53/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3759 - acc: 0.8710
#
# Epoch 00053: loss did not improve from 0.36915
# Epoch 54/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3720 - acc: 0.8728
#
# Epoch 00054: loss did not improve from 0.36915
# Epoch 55/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3600 - acc: 0.8762
#
# Epoch 00055: loss improved from 0.36915 to 0.36002, saving model to seg_model.h5
# Epoch 56/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3608 - acc: 0.8758
#
# Epoch 00056: loss did not improve from 0.36002
# Epoch 57/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3584 - acc: 0.8769
#
# Epoch 00057: loss improved from 0.36002 to 0.35837, saving model to seg_model.h5
# Epoch 58/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3714 - acc: 0.8722
#
# Epoch 00058: loss did not improve from 0.35837
# Epoch 59/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3553 - acc: 0.8776
#
# Epoch 00059: loss improved from 0.35837 to 0.35531, saving model to seg_model.h5
# Epoch 60/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3431 - acc: 0.8818
#
# Epoch 00060: loss improved from 0.35531 to 0.34308, saving model to seg_model.h5
# Epoch 61/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3476 - acc: 0.8796
#
# Epoch 00061: loss did not improve from 0.34308
# Epoch 62/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3507 - acc: 0.8794
#
# Epoch 00062: loss did not improve from 0.34308
# Epoch 63/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3387 - acc: 0.8829
#
# Epoch 00063: loss improved from 0.34308 to 0.33871, saving model to seg_model.h5
# Epoch 64/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3273 - acc: 0.8867
#
# Epoch 00064: loss improved from 0.33871 to 0.32732, saving model to seg_model.h5
# Epoch 65/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3245 - acc: 0.8881
#
# Epoch 00065: loss improved from 0.32732 to 0.32445, saving model to seg_model.h5
# Epoch 66/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3215 - acc: 0.8891
#
# Epoch 00066: loss improved from 0.32445 to 0.32150, saving model to seg_model.h5
# Epoch 67/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3208 - acc: 0.8891
#
# Epoch 00067: loss improved from 0.32150 to 0.32076, saving model to seg_model.h5
# Epoch 68/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3219 - acc: 0.8885
#
# Epoch 00068: loss did not improve from 0.32076
# Epoch 69/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3153 - acc: 0.8907
#
# Epoch 00069: loss improved from 0.32076 to 0.31530, saving model to seg_model.h5
# Epoch 70/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3145 - acc: 0.8914
#
# Epoch 00070: loss improved from 0.31530 to 0.31447, saving model to seg_model.h5
# Epoch 71/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3062 - acc: 0.8938
#
# Epoch 00071: loss improved from 0.31447 to 0.30619, saving model to seg_model.h5
# Epoch 72/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3032 - acc: 0.8950
#
# Epoch 00072: loss improved from 0.30619 to 0.30318, saving model to seg_model.h5
# Epoch 73/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.3004 - acc: 0.8960
#
# Epoch 00073: loss improved from 0.30318 to 0.30040, saving model to seg_model.h5
# Epoch 74/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2941 - acc: 0.8983
#
# Epoch 00074: loss improved from 0.30040 to 0.29408, saving model to seg_model.h5
# Epoch 75/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2968 - acc: 0.8970
#
# Epoch 00075: loss did not improve from 0.29408
# Epoch 76/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2978 - acc: 0.8964
#
# Epoch 00076: loss did not improve from 0.29408
# Epoch 77/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2837 - acc: 0.9017
#
# Epoch 00077: loss improved from 0.29408 to 0.28372, saving model to seg_model.h5
# Epoch 78/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2812 - acc: 0.9024
#
# Epoch 00078: loss improved from 0.28372 to 0.28120, saving model to seg_model.h5
# Epoch 79/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2774 - acc: 0.9039
#
# Epoch 00079: loss improved from 0.28120 to 0.27742, saving model to seg_model.h5
# Epoch 80/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2823 - acc: 0.9021
#
# Epoch 00080: loss did not improve from 0.27742
# Epoch 81/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2735 - acc: 0.9051
#
# Epoch 00081: loss improved from 0.27742 to 0.27351, saving model to seg_model.h5
# Epoch 82/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2659 - acc: 0.9076
#
# Epoch 00082: loss improved from 0.27351 to 0.26593, saving model to seg_model.h5
# Epoch 83/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2776 - acc: 0.9034
#
# Epoch 00083: loss did not improve from 0.26593
# Epoch 84/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2779 - acc: 0.9034
#
# Epoch 00084: loss did not improve from 0.26593
# Epoch 85/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2643 - acc: 0.9081
#
# Epoch 00085: loss improved from 0.26593 to 0.26428, saving model to seg_model.h5
# Epoch 86/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2605 - acc: 0.9097
#
# Epoch 00086: loss improved from 0.26428 to 0.26047, saving model to seg_model.h5
# Epoch 87/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2554 - acc: 0.9114
#
# Epoch 00087: loss improved from 0.26047 to 0.25541, saving model to seg_model.h5
# Epoch 88/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2600 - acc: 0.9094
#
# Epoch 00088: loss did not improve from 0.25541
# Epoch 89/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2639 - acc: 0.9086
#
# Epoch 00089: loss did not improve from 0.25541
# Epoch 90/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2568 - acc: 0.9108
#
# Epoch 00090: loss did not improve from 0.25541
# Epoch 91/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2544 - acc: 0.9116
#
# Epoch 00091: loss improved from 0.25541 to 0.25436, saving model to seg_model.h5
# Epoch 92/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2427 - acc: 0.9154
#
# Epoch 00092: loss improved from 0.25436 to 0.24274, saving model to seg_model.h5
# Epoch 93/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2380 - acc: 0.9171
#
# Epoch 00093: loss improved from 0.24274 to 0.23800, saving model to seg_model.h5
# Epoch 94/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2387 - acc: 0.9168
#
# Epoch 00094: loss did not improve from 0.23800
# Epoch 95/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2432 - acc: 0.9153
#
# Epoch 00095: loss did not improve from 0.23800
# Epoch 96/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2457 - acc: 0.9142
#
# Epoch 00096: loss did not improve from 0.23800
# Epoch 97/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2440 - acc: 0.9150
#
# Epoch 00097: loss did not improve from 0.23800
# Epoch 98/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2277 - acc: 0.9207
#
# Epoch 00098: loss improved from 0.23800 to 0.22773, saving model to seg_model.h5
# Epoch 99/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2232 - acc: 0.9221
#
# Epoch 00099: loss improved from 0.22773 to 0.22321, saving model to seg_model.h5
# Epoch 100/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2203 - acc: 0.9231
#
# Epoch 00100: loss improved from 0.22321 to 0.22027, saving model to seg_model.h5
# Epoch 101/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2316 - acc: 0.9193
#
# Epoch 00101: loss did not improve from 0.22027
# Epoch 102/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2243 - acc: 0.9218
#
# Epoch 00102: loss did not improve from 0.22027
# Epoch 103/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2176 - acc: 0.9239
#
# Epoch 00103: loss improved from 0.22027 to 0.21765, saving model to seg_model.h5
# Epoch 104/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2105 - acc: 0.9264
#
# Epoch 00104: loss improved from 0.21765 to 0.21054, saving model to seg_model.h5
# Epoch 105/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2123 - acc: 0.9257
#
# Epoch 00105: loss did not improve from 0.21054
# Epoch 106/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2138 - acc: 0.9254
#
# Epoch 00106: loss did not improve from 0.21054
# Epoch 107/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2141 - acc: 0.9249
#
# Epoch 00107: loss did not improve from 0.21054
# Epoch 108/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2591 - acc: 0.9097
#
# Epoch 00108: loss did not improve from 0.21054
# Epoch 109/200
# 65/65 [==============================] - 11s 173ms/step - loss: 0.2187 - acc: 0.9234
#
# Epoch 00109: loss did not improve from 0.21054

# %%
plt.plot(hist.history['loss'])
plt.title("model loss")
plt.ylabel("Loss")
plt.xlabel("Epochs")
plt.show()

# %%
plt.plot(hist.history["acc"])
plt.title("model accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epochs")
plt.show()

# %%
pred=mymodel.predict(x_test)
y_pred=tf.argmax(pred,axis=-1)

# %%
def show_predications(x_test,y_test,y_pred):
    idx=np.random.randint(0,len(y_pred))
    fig, axes = plt.subplots(1,3,figsize=(10,10))
    axes[0].imshow(x_test[idx])
    axes[0].set_title("original")
    axes[1].imshow(y_test[idx])
    axes[1].set_title("mask")
    axes[2].imshow(y_pred[idx])
    axes[2].set_title("predicated")

# %%
for i in range(3):
    show_predications(x_test,y_test,y_pred)
